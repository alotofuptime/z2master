# %%
import pandas as pd

# %%
academy = pd.read_csv("ztm.csv", index_col=False)

# %%
academy = academy.drop(columns="Unnamed: 0")
academy.head()
# Out:
#                                                title  \
# 0                  JavaScript: The Advanced Concepts
# 1  The Complete Guide to Freelancing in 2022: Zer...
# 2  Complete Ethical Hacking Bootcamp 2022: Zero t...
# 3  Complete Machine Learning and Data Science: Ze...
# 4  Complete Python Developer in 2022: Zero to Mas...
#
#                                              modules  \
# 0  ['Introduction', 'JavaScript Foundation', 'Jav...
# 1  ['Getting Started', 'Profile Module - Building...
# 2  ['Introduction', 'Setting Up Our Hacking Lab',...
# 3  ['Introduction', 'Machine Learning 101', 'Mach...
# 4  ['Introduction', 'Python Introduction', 'Pytho...
#
#                                    taught by  hours  lessons
# 0                         ['Andrei Neagoie']   25.5      228
# 1                            ['Paul Mendes']   10.0       53
# 2  ['Andrei Neagoie', 'Aleksa Tamburkovski']   27.5      249
# 3        ['Andrei Neagoie', 'Daniel Bourke']   43.5      377
# ...

# %%
academy.columns
# Out:
# Index(['title', 'modules', 'taught by', 'hours', 'lessons'], dtype='object')

# %%
academy.sort_values("lessons", ascending=False)
# Out:
#                                                 title  \
# 30  The Complete Junior to Senior Web Developer Ro...
# 23  TensorFlow Developer Certificate in 2022: Zero...
# 19  Complete Node.js Developer in 2022: Zero to Ma...
# 18  Complete Next.js Developer in 2022: Zero to Ma...
# 8   The Complete Web Developer in 2022: Zero to Ma...
# 5   Complete React Developer in 2022 (w/ Redux, Ho...
# 3   Complete Machine Learning and Data Science: Ze...
# 21  Complete React Native Developer in 2022: Zero ...
# 4   Complete Python Developer in 2022: Zero to Mas...
# 24  Complete Vue Developer in 2022 (w/ Vuex, Compo...
# 14  Complete Angular Developer in 2022: Zero to Ma...
# 28  Master the Coding Interview: Big Tech (FAANG) ...
# 6   Complete SQL + Databases Bootcamp: Zero to Mas...
# 7   Complete Web & Mobile Designer in 2022: UI/UX,...
# 27  Master the Coding Interview: Data Structures +...
# 2   Complete Ethical Hacking Bootcamp 2022: Zero t...
# ...

# %%
academy.dtypes
# Out:
# title         object
# modules       object
# taught by     object
# hours        float64
# lessons        int64
# dtype: object

# %%
academy.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
academy.describe()
# Out:
#            hours     lessons
# count  31.000000   31.000000
# mean   24.209677  237.451613
# std    14.699645  126.708547
# min     2.000000   21.000000
# 25%    11.500000  120.000000
# 50%    25.500000  249.000000
# 75%    34.750000  337.500000
# max    63.500000  436.000000

# %%
academy.T
# Out:
#                                                           0   \
# title                      JavaScript: The Advanced Concepts
# modules    ['Introduction', 'JavaScript Foundation', 'Jav...
# taught by                                 ['Andrei Neagoie']
# hours                                                   25.5
# lessons                                                  228
#
#                                                           1   \
# title      The Complete Guide to Freelancing in 2022: Zer...
# modules    ['Getting Started', 'Profile Module - Building...
# taught by                                    ['Paul Mendes']
# hours                                                   10.0
# lessons                                                   53
#
#                                                           2   \
# title      Complete Ethical Hacking Bootcamp 2022: Zero t...
# modules    ['Introduction', 'Setting Up Our Hacking Lab',...
# ...

# %%
academy.sort_index(axis=1, ascending=True)
# Out:
#     hours  lessons                                            modules  \
# 0    25.5      228  ['Introduction', 'JavaScript Foundation', 'Jav...
# 1    10.0       53  ['Getting Started', 'Profile Module - Building...
# 2    27.5      249  ['Introduction', 'Setting Up Our Hacking Lab',...
# 3    43.5      377  ['Introduction', 'Machine Learning 101', 'Mach...
# 4    30.5      332  ['Introduction', 'Python Introduction', 'Pytho...
# 5    42.5      380  ['Introduction', 'React Key Concepts', 'React ...
# 6    24.5      278  ['Introduction', 'History And Story Of Data', ...
# 7    26.0      264  ['Introduction', 'Section 1: GETTING STARTED -...
# 8    38.0      383  ['Introduction', 'How The Internet Works', 'Hi...
# 9    13.5      174  ['Introduction', 'Deno Foundations', 'Deno vs ...
# 10   21.0      213  ['Getting Started', 'Setting Up the Environmen...
# 11   14.0      107  ['Introduction', 'Module 1: Excel 101', 'Modul...
# ...

# %%
academy["modules"][0]
# academy["title"][0]
# Out:
# "['Introduction', 'JavaScript Foundation', 'Javascript Foundation II', 'Types in JavaScript', 'The 2 Pillars: Closures and Prototypal Inheritance', 'Object Oriented Programming', 'Functional Programming', 'OOP vs FP', 'Asynchronous JavaScript', 'Modules in JavaScript', 'Error Handling', 'Thank You', 'Bonus: Data Structures In JavaScript', 'Appendix I: Javascript Basics', 'Appendix II: Intermediate  Javascript', 'Bonus: Extra Bits']"

# %%
instructors = academy["taught by"]
academy.loc[[0], "taught by"]
# Out:
# 0    ['Andrei Neagoie']
# Name: taught by, dtype: object

# %%
academy.loc[0:]["taught by"]
# Out:
# 0                            ['Andrei Neagoie']
# 1                               ['Paul Mendes']
# 2     ['Andrei Neagoie', 'Aleksa Tamburkovski']
# 3           ['Andrei Neagoie', 'Daniel Bourke']
# 4                            ['Andrei Neagoie']
# 5             ['Andrei Neagoie', 'Yihua Zhang']
# 6                ['Andrei Neagoie', 'Mo Binni']
# 7         ['Andrei Neagoie', 'Daniel Schifano']
# 8                            ['Andrei Neagoie']
# 9       ['Andrei Neagoie', 'Adam Odziemkowski']
# 10                        ['Andrei Dumitrescu']
# 11     ['Travis\r\n                    Cuzick']
# 12                                 ['Mo Binni']
# 13           ['Andrei Neagoie', 'Jacinto Wong']
# 14                          ['Luis Ramirez Jr']
# 15                          ['Andrea Bizzotto']
# 16                            ['Jayson Lennon']
# 17                          ['Daniel Schifano']
# 18        ['Andrei Neagoie', 'Ankita Kulkarni']
# 19      ['Andrei Neagoie', 'Adam Odziemkowski']
# ...

# %%
academy.loc[0:, ["lessons"]] > 400
# Out:
#     lessons
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19     True
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True

# %%
academy.loc[3:5]
# Out:
#                                                title  \
# 3  Complete Machine Learning and Data Science: Ze...
# 4  Complete Python Developer in 2022: Zero to Mas...
# 5  Complete React Developer in 2022 (w/ Redux, Ho...
#
#                                              modules  \
# 3  ['Introduction', 'Machine Learning 101', 'Mach...
# 4  ['Introduction', 'Python Introduction', 'Pytho...
# 5  ['Introduction', 'React Key Concepts', 'React ...
#
#                              taught by  hours  lessons
# 3  ['Andrei Neagoie', 'Daniel Bourke']   43.5      377
# 4                   ['Andrei Neagoie']   30.5      332
# 5    ['Andrei Neagoie', 'Yihua Zhang']   42.5      380

# %%
instructors.iloc[0]
# Out:
# "['Andrei Neagoie']"

# %%
academy.iloc[1:3, 0:3]
# Out:
#                                                title  \
# 1  The Complete Guide to Freelancing in 2022: Zer...
# 2  Complete Ethical Hacking Bootcamp 2022: Zero t...
#
#                                              modules  \
# 1  ['Getting Started', 'Profile Module - Building...
# 2  ['Introduction', 'Setting Up Our Hacking Lab',...
#
#                                    taught by
# 1                            ['Paul Mendes']
# 2  ['Andrei Neagoie', 'Aleksa Tamburkovski']

# %%
# first inner brackets = rows
# second inner brackets = columns
academy.iloc[[1, 3, 4], [1, 3]]
# Out:
#                                              modules  hours
# 1  ['Getting Started', 'Profile Module - Building...   10.0
# 3  ['Introduction', 'Machine Learning 101', 'Mach...   43.5
# 4  ['Introduction', 'Python Introduction', 'Pytho...   30.5

# %%
# first slice = rows
# second slice = columns
academy.iloc[1:3, :]
# Out:
#                                                title  \
# 1  The Complete Guide to Freelancing in 2022: Zer...
# 2  Complete Ethical Hacking Bootcamp 2022: Zero t...
#
#                                              modules  \
# 1  ['Getting Started', 'Profile Module - Building...
# 2  ['Introduction', 'Setting Up Our Hacking Lab',...
#
#                                    taught by  hours  lessons
# 1                            ['Paul Mendes']   10.0       53
# 2  ['Andrei Neagoie', 'Aleksa Tamburkovski']   27.5      249

# %%
academy.iloc[1, 1]
# Out:
# "['Getting Started', 'Profile Module - Building a Rockstar Freelance Profile', 'Deals Module - Finding & Closing High-Ticket Clients', 'Growth Module - Managing & Scaling Your Freelance Business', 'Skills Module - Profitable Freelance Skills', 'Success Module - Setting Yourself Up For Freelance Success', 'Mindset Module - Developing a Millionaire Mindset', 'Where To Go From Here?']"

# %%
academy.loc[1]
# Out:
# title        The Complete Guide to Freelancing in 2022: Zer...
# modules      ['Getting Started', 'Profile Module - Building...
# taught by                                      ['Paul Mendes']
# hours                                                     10.0
# lessons                                                     53
# Name: 1, dtype: object

# %%
academy.loc[lambda df: df["lessons"] > 400, :]
# Out:
#                                                 title  \
# 18  Complete Next.js Developer in 2022: Zero to Ma...
# 19  Complete Node.js Developer in 2022: Zero to Ma...
# 23  TensorFlow Developer Certificate in 2022: Zero...
# 30  The Complete Junior to Senior Web Developer Ro...
#
#                                               modules  \
# 18  ['Introduction', 'Next.js Fundamentals (includ...
# 19  ['Introduction', 'Node.js Fundamentals: Founda...
# 23  ['Introduction', 'Deep Learning and TensorFlow...
# 30  ['Introduction', 'SSH', 'Performance Part 1', ...
#
#                                   taught by  hours  lessons
# 18    ['Andrei Neagoie', 'Ankita Kulkarni']   36.5      405
# 19  ['Andrei Neagoie', 'Adam Odziemkowski']   46.0      413
# 23                        ['Daniel Bourke']   63.5      419
# 30                       ['Andrei Neagoie']   37.0      436

# %%
academy.loc[lambda df: df["hours"] > 40, :]
# Out:
#                                                 title  \
# 3   Complete Machine Learning and Data Science: Ze...
# 5   Complete React Developer in 2022 (w/ Redux, Ho...
# 19  Complete Node.js Developer in 2022: Zero to Ma...
# 23  TensorFlow Developer Certificate in 2022: Zero...
#
#                                               modules  \
# 3   ['Introduction', 'Machine Learning 101', 'Mach...
# 5   ['Introduction', 'React Key Concepts', 'React ...
# 19  ['Introduction', 'Node.js Fundamentals: Founda...
# 23  ['Introduction', 'Deep Learning and TensorFlow...
#
#                                   taught by  hours  lessons
# 3       ['Andrei Neagoie', 'Daniel Bourke']   43.5      377
# 5         ['Andrei Neagoie', 'Yihua Zhang']   42.5      380
# 19  ['Andrei Neagoie', 'Adam Odziemkowski']   46.0      413
# 23                        ['Daniel Bourke']   63.5      419

# %%
academy.loc[:9, lambda df: ["title", "taught by"]]
# Out:
#                                                title  \
# 0                  JavaScript: The Advanced Concepts
# 1  The Complete Guide to Freelancing in 2022: Zer...
# 2  Complete Ethical Hacking Bootcamp 2022: Zero t...
# 3  Complete Machine Learning and Data Science: Ze...
# 4  Complete Python Developer in 2022: Zero to Mas...
# 5  Complete React Developer in 2022 (w/ Redux, Ho...
# 6  Complete SQL + Databases Bootcamp: Zero to Mas...
# 7  Complete Web & Mobile Designer in 2022: UI/UX,...
# 8  The Complete Web Developer in 2022: Zero to Ma...
# 9           Deno: The Complete Guide Zero to Mastery
#
#                                    taught by
# 0                         ['Andrei Neagoie']
# 1                            ['Paul Mendes']
# 2  ['Andrei Neagoie', 'Aleksa Tamburkovski']
# 3        ['Andrei Neagoie', 'Daniel Bourke']
# 4                         ['Andrei Neagoie']
# 5          ['Andrei Neagoie', 'Yihua Zhang']
# 6             ['Andrei Neagoie', 'Mo Binni']
# ...

# %%
academy.iloc[:5, lambda df: [0, 1]]
# Out:
#                                                title  \
# 0                  JavaScript: The Advanced Concepts
# 1  The Complete Guide to Freelancing in 2022: Zer...
# 2  Complete Ethical Hacking Bootcamp 2022: Zero t...
# 3  Complete Machine Learning and Data Science: Ze...
# 4  Complete Python Developer in 2022: Zero to Mas...
#
#                                              modules
# 0  ['Introduction', 'JavaScript Foundation', 'Jav...
# 1  ['Getting Started', 'Profile Module - Building...
# 2  ['Introduction', 'Setting Up Our Hacking Lab',...
# 3  ['Introduction', 'Machine Learning 101', 'Mach...
# 4  ['Introduction', 'Python Introduction', 'Pytho...

# %%
academy[lambda df: df.columns[0]]
# Out:
# 0                     JavaScript: The Advanced Concepts
# 1     The Complete Guide to Freelancing in 2022: Zer...
# 2     Complete Ethical Hacking Bootcamp 2022: Zero t...
# 3     Complete Machine Learning and Data Science: Ze...
# 4     Complete Python Developer in 2022: Zero to Mas...
# 5     Complete React Developer in 2022 (w/ Redux, Ho...
# 6     Complete SQL + Databases Bootcamp: Zero to Mas...
# 7     Complete Web & Mobile Designer in 2022: UI/UX,...
# 8     The Complete Web Developer in 2022: Zero to Ma...
# 9              Deno: The Complete Guide Zero to Mastery
# 10    DevOps Bootcamp: Learn Linux & Become a Linux ...
# 11                  The Excel Bootcamp: Zero to Mastery
# 12                        NFT 101: Introduction to NFTs
# 13    JavaScript Web Projects: 20 Projects to Build ...
# 14    Complete Angular Developer in 2022: Zero to Ma...
# 15                 Dart: The Complete Developer's Guide
# 16    Go Programming (Golang): The Complete Develope...
# ...

# %%
academy.head()
academy["lessons"].apply(lambda x: float(x))
# Out:
# 0     228.0
# 1      53.0
# 2     249.0
# 3     377.0
# 4     332.0
# 5     380.0
# 6     278.0
# 7     264.0
# 8     383.0
# 9     174.0
# 10    213.0
# 11    107.0
# 12     21.0
# 13    236.0
# 14    296.0
# 15    184.0
# 16    100.0
# 17    130.0
# 18    405.0
# 19    413.0
# 20     95.0
# 21    343.0
# 22    228.0
# 23    419.0
# 24    296.0
# 25     26.0
# 26    110.0
# 27    260.0
# 28    287.0
# 29     38.0
# 30    436.0
# Name: lessons, dtype: float64

# %%
academy["taught by"] = academy["taught by"].apply(eval)

# %%
academy["modules"] = academy["modules"].apply(eval)

# %%
[type(x) for x in academy["modules"]]
# Out:
# [list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list,
#  list]

# %%
academy
# Out:
#                                                 title  \
# 0                   JavaScript: The Advanced Concepts
# 1   The Complete Guide to Freelancing in 2022: Zer...
# 2   Complete Ethical Hacking Bootcamp 2022: Zero t...
# 3   Complete Machine Learning and Data Science: Ze...
# 4   Complete Python Developer in 2022: Zero to Mas...
# 5   Complete React Developer in 2022 (w/ Redux, Ho...
# 6   Complete SQL + Databases Bootcamp: Zero to Mas...
# 7   Complete Web & Mobile Designer in 2022: UI/UX,...
# 8   The Complete Web Developer in 2022: Zero to Ma...
# 9            Deno: The Complete Guide Zero to Mastery
# 10  DevOps Bootcamp: Learn Linux & Become a Linux ...
# 11                The Excel Bootcamp: Zero to Mastery
# 12                      NFT 101: Introduction to NFTs
# 13  JavaScript Web Projects: 20 Projects to Build ...
# 14  Complete Angular Developer in 2022: Zero to Ma...
# 15               Dart: The Complete Developer's Guide
# ...

# %%
academy["taught by"][11][0] = academy["taught by"][11][0].replace("\r\n", "")

# %%
travis_cuzick = academy["taught by"][11][0]

# %%
travis = travis_cuzick.split(" ")[0]
travis
cuzick = travis_cuzick.split(" ")[-1]
cuzick
f"{travis} {cuzick}"
# Out:
# 'Travis Cuzick'

# %%
academy["taught by"][11][0] = f"{travis} {cuzick}"
academy["taught by"][11]
# Out:
# ['Travis Cuzick']

# %%
academy[:12]
# Out:
#                                                 title  \
# 0                   JavaScript: The Advanced Concepts
# 1   The Complete Guide to Freelancing in 2022: Zer...
# 2   Complete Ethical Hacking Bootcamp 2022: Zero t...
# 3   Complete Machine Learning and Data Science: Ze...
# 4   Complete Python Developer in 2022: Zero to Mas...
# 5   Complete React Developer in 2022 (w/ Redux, Ho...
# 6   Complete SQL + Databases Bootcamp: Zero to Mas...
# 7   Complete Web & Mobile Designer in 2022: UI/UX,...
# 8   The Complete Web Developer in 2022: Zero to Ma...
# 9            Deno: The Complete Guide Zero to Mastery
# 10  DevOps Bootcamp: Learn Linux & Become a Linux ...
# 11                The Excel Bootcamp: Zero to Mastery
#
#                                               modules  \
# 0   [Introduction, JavaScript Foundation, Javascri...
# 1   [Getting Started, Profile Module - Building a ...
# 2   [Introduction, Setting Up Our Hacking Lab, Lin...
# ...

# %%
academy["lessons"] = academy["lessons"].apply(lambda x: float(x))

# %%
academy
# Out:
#                                                 title  \
# 0                   JavaScript: The Advanced Concepts
# 1   The Complete Guide to Freelancing in 2022: Zer...
# 2   Complete Ethical Hacking Bootcamp 2022: Zero t...
# 3   Complete Machine Learning and Data Science: Ze...
# 4   Complete Python Developer in 2022: Zero to Mas...
# 5   Complete React Developer in 2022 (w/ Redux, Ho...
# 6   Complete SQL + Databases Bootcamp: Zero to Mas...
# 7   Complete Web & Mobile Designer in 2022: UI/UX,...
# 8   The Complete Web Developer in 2022: Zero to Ma...
# 9            Deno: The Complete Guide Zero to Mastery
# 10  DevOps Bootcamp: Learn Linux & Become a Linux ...
# 11                The Excel Bootcamp: Zero to Mastery
# 12                      NFT 101: Introduction to NFTs
# 13  JavaScript Web Projects: 20 Projects to Build ...
# 14  Complete Angular Developer in 2022: Zero to Ma...
# 15               Dart: The Complete Developer's Guide
# ...

# %%
academy.to_csv("ztm.csv")
